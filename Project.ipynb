# %% [markdown]
# Здесь все загружаемые модули, словари и функции которые понадобятся для работы с программой. Запустите их сразу

# %%
import numpy as np
import pandas as pd
from IPython.core.display import HTML
import requests
from bs4 import BeautifulSoup
import sys
!"{sys.executable}" -m pip install selenium
!"{sys.executable}" -m pip install plotly_express
import plotly 
import plotly_express as px
from selenium.webdriver import Chrome
from time import sleep
from selenium.webdriver.common import keys
from selenium.common.exceptions import NoSuchElementException
from IPython.display import clear_output, display
from datetime import datetime, date, time
from ipywidgets import Button
# Out:
# Requirement already satisfied: selenium in c:\users\vadim\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\vadim\anaconda3\lib\site-packages (from selenium) (1.24.1)
# Requirement already satisfied: plotly_express in c:\users\vadim\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: numpy>=1.11 in c:\users\vadim\anaconda3\lib\site-packages (from plotly_express) (1.15.4)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\vadim\anaconda3\lib\site-packages (from plotly_express) (0.23.4)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\vadim\anaconda3\lib\site-packages (from plotly_express) (0.9.0)
# Requirement already satisfied: plotly>=3.7.1 in c:\users\vadim\anaconda3\lib\site-packages (from plotly_express) (3.7.1)
# Requirement already satisfied: scipy>=0.18 in c:\users\vadim\anaconda3\lib\site-packages (from plotly_express) (1.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\vadim\anaconda3\lib\site-packages (from plotly_express) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\vadim\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2.7.5)
# Requirement already satisfied: pytz>=2011k in c:\users\vadim\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2018.7)
# Requirement already satisfied: nbformat>=4.2 in c:\users\vadim\anaconda3\lib\site-packages (from plotly>=3.7.1->plotly_express) (4.4.0)
# Requirement already satisfied: requests in c:\users\vadim\anaconda3\lib\site-packages (from plotly>=3.7.1->plotly_express) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\vadim\anaconda3\lib\site-packages (from plotly>=3.7.1->plotly_express) (1.3.3)
# Requirement already satisfied: six in c:\users\vadim\anaconda3\lib\site-packages (from plotly>=3.7.1->plotly_express) (1.12.0)
# Requirement already satisfied: decorator>=4.0.6 in c:\users\vadim\anaconda3\lib\site-packages (from plotly>=3.7.1->plotly_express) (4.3.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbformat>=4.2->plotly>=3.7.1->plotly_express) (4.3.2)
# Requirement already satisfied: jupyter-core in c:\users\vadim\anaconda3\lib\site-packages (from nbformat>=4.2->plotly>=3.7.1->plotly_express) (4.4.0)
# Requirement already satisfied: ipython-genutils in c:\users\vadim\anaconda3\lib\site-packages (from nbformat>=4.2->plotly>=3.7.1->plotly_express) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbformat>=4.2->plotly>=3.7.1->plotly_express) (2.6.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\vadim\anaconda3\lib\site-packages (from requests->plotly>=3.7.1->plotly_express) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vadim\anaconda3\lib\site-packages (from requests->plotly>=3.7.1->plotly_express) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\vadim\anaconda3\lib\site-packages (from requests->plotly>=3.7.1->plotly_express) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\vadim\anaconda3\lib\site-packages (from requests->plotly>=3.7.1->plotly_express) (2.8)

# %%
format_str = '%d/%m/%Y' 

month_conv = {' янв. ': '/01/',
              ' фев. ': '/02/',
              ' мар. ': '/03/',
              ' апр. ': '/04/',
              ' мая. ': '/05/',
              ' июн. ': '/06/',
              ' июл. ': '/07/',
              ' авг. ': '/08/',
              ' сен. ': '/09/',
              ' окт. ': '/10/',
              ' ноя. ': '/11/',
              ' дек. ': '/12/'}

# %%
def sortby_Name(df):
    return(df.sort_values("Game Name"))

def sortby_Rating(df):
    df['temp_column'] = [0 if rt =='' else int(rt[:-1]) for rt in df["Rating"]]
    df = df.sort_values("temp_column", ascending=False)
    df = df.drop("temp_column", axis = 1)
    return(df)

def sortby_Num_Rating(df):
    df['temp_column'] = [0 if nrt =='' else int(nrt.replace(",", "")) for nrt in df["Number of Ratings"]]
    df = df.sort_values("temp_column", ascending=False)
    df = df.drop("temp_column", axis=1)
    return(df)

def sortby_Price(df):
    df['temp_column'] = [-1 if pr =='' else 0 if (pr =='Бесплатно' or pr =='Демо') else float(pr.replace("pуб.", "").replace(",", ".")) for pr in df["Ordinary Price"]]
    df = df.sort_values("temp_column", ascending=False)
    df = df.drop("temp_column", axis=1)
    return(df)

def sortby_Price_Now(df):
    df['temp_column'] = [-1 if pr =='' else 0 if (pr =='Бесплатно' or pr =='Демо') else float(pr.replace("pуб.", "").replace(",", ".")) for pr in df["Price Now"]]
    df = df.sort_values("temp_column", ascending=False)
    df = df.drop("temp_column", axis=1)
    return(df)

def standart_sort(df):
    return(df.sort_index())

def sortby_Date(df):
    df['temp_column'] = [ date(1,1,1) if dt =='' else dt for dt in df["Release Date"]]
    dtt = []
    for dt in df['temp_column']:
        if dt !=date(1,1,1):
            for key in month_conv.keys():
                dt = dt.replace(key, month_conv[key])
            dtt.append(datetime.strptime(dt, format_str).date())
        else:
            dtt.append(dt)
    df['temp_column'] = dtt
    df = df.sort_values("temp_column", ascending=False)
    df = df.drop("temp_column", axis=1)
    return(df)

# %% [markdown]
# Сама программа, для её работы понадобится файл Labels.txt, который будет в архиве и будет необходимо припосать путь к нему в первой строке программы.
# В вводах меток и сортироки можно писать что угодно программа просто не пустит неправильные значения, но в других вводах пожалуйста пишите в нужном формате.
# Так же необходим хром драйвер и к нему тоже нужно будет прописать путь в 23 строке.

# %% [markdown]
# Так как у разных людей разная скорость интернета страницы могут грузиться дольше чем считывается информация, поэтому настройте параметры команды sleep под себя (К примеру если в таблички повторяются игры, то его следует увеличить). Так же не советую писать по одной метке или all, это ну очень много игр, а значит программа будет работать долго.

# %% [markdown]
# Достаточно неплохой вариант для запуска программы по меткам: 'Инди, Шахматы'. Там 2 страницы, 40 игр.

# %%
# ........................................................................................................................................................................................................................................
f = open(r'C:\Users\vadim\Desktop\Labels.txt', 'r')
Labels = f.read().split("\n")
print("Введите все метки через запятую и пробел, если не знаете как пишутся метки напишите 'метки'\nЕсли хотите вывести все игры, то пишите All. ")
Labs = input().split(", ")
if Labs == ["Тодд Говард"]:
    print("Купи Скайрим!")
while True:
    if set(Labs).issubset(Labels) or Labs ==['All']:
        break
    elif ((Labs == ['метки']) or (Labs==["'метки'"])):
        print("метки в Steam: ")
        print(Labels)
        print("Введите метки игры:")
        Labs = input().split(", ")
    else:
        print("вводите только метки указанные в списке 'метки'")
        Labs = input().split(", ")
f.close() 

# часть принимающая общий список меток и частный от человека.


driver = Chrome(executable_path="C://Users/vadim/Desktop/chromedriver.exe")
driver.get("https://store.steampowered.com/search/?")
Sett = driver.find_element_by_css_selector(".dropdown")
Sett.click()
Sett = driver.find_element_by_css_selector(".item~ .item+ .item")
Sett.click()                                                     #эти четыре строки добавляют в список 600 игр изключённых из-за фильтра стима.
if Labs !=['All']:
    form  = driver.find_elements_by_css_selector("#TagSuggest")[0]
    for Lab in Labs:
        form.send_keys(Lab)
        cell = driver.find_element_by_xpath("//div[@data-loc='" + Lab + "']")
        cell.click()
        form.clear()
sleep(10)

# часть оставляющая в списке только игры с нужными метками

Pics = []
Names = []
Dates = []
Rates = []
Rates_N = []
Prices = []
Prices_Now = [] #еее, скидки!

for i in range(2400):
    
    Pics_on_Page = driver.find_elements_by_css_selector("#search_result_container img")
    for Pic in Pics_on_Page:
        Pics.append('<img src="'+ Pic.get_attribute('src') + '" width="60" >')
    
    Names_on_page = driver.find_elements_by_css_selector(".title")
    Names.extend([name.text for name in Names_on_page])
    
    Dates_on_page = driver.find_elements_by_class_name("search_released")
    Dates.extend([date.text for date in Dates_on_page])
    
    Rates_on_page = driver.find_elements_by_class_name("search_reviewscore")
    for R in Rates_on_page:
        try:
            R = R.find_element_by_class_name("search_review_summary").get_attribute("data-tooltip-html")
            R_N = R[R.find("из")+3:R.find("об")]
            R = R[R.find("<")+4:R.find("%")+1]
        except NoSuchElementException:
            R = ''
            R_N=''
        Rates.append(R)
        Rates_N.append(R_N)
    
    Prices_on_page  =  driver.find_elements_by_class_name("search_price")
    for Price in Prices_on_page:
        Price = Price.text
        if Price.count('pуб') != 2:
            Prices.append(Price)
            Prices_Now.append(Price)
        else:
            Prices.append(Price.split("\n")[0])
            Prices_Now.append(Price.split("\n")[1])
    
    try:
        arrow = driver.find_element_by_css_selector("a+ .pagebtn")
        arrow.click()
        sleep(10)
    except Exception as e:
        break
        
driver.quit()
        
clear_output()
        
d = {"Icon":Pics, "Game Name":Names, "Release Date": Dates, "Rating": Rates,"Number of Ratings":Rates_N, "Ordinary Price": Prices, "Price Now":Prices_Now}
df = pd.DataFrame(d)

if len(df.index) == 0:
    sys.exit("Игр с таким набором меток нет")

display(HTML(df.style.set_properties(**{'index-align': 'left', 'text-align': 'left'}).render()))

# а теперь сортировки

func_dic = {"Game Name": sortby_Name, "Release Date": sortby_Date, "Rating": sortby_Rating, "Number of Ratings": sortby_Num_Rating, "Ordinary Price":sortby_Price, "Price Now": sortby_Price_Now, "Standart": standart_sort}

print("по какой характеристике сортируем? Если не хотите сортировать напишите стоп.")
sleep(1)
Sor = input()

while Sor != "стоп":
    sleep(2)
    if Sor == "вводите нормально":
        print("vvedite normalno")
    elif (Sor in func_dic) or (Sor == "стоп"):
        df = func_dic[Sor](df)
        clear_output()
        display(HTML(df.style.set_properties(**{'index-align': 'left', 'text-align': 'left'}).render()))
        print("Можете отсортировать ещё раз, если хотите вернуться к стандартной сортировке напишите 'Standart', Если хотети прекратить напишите 'стоп'")
    else:
        print("вводите нормально")
    Sor = input()
    
    
#уберём игры которые не укладываются в диапазон цен/оценок

print("введите диапазон цен в формате 'от N до M'(N,M >= 0). Можно опустить одну часть или оставить пустой ввод для всех игр")
PrRange = input()
PrRange = PrRange.split(" ")
if 'от' in PrRange:
    PrRangeL = int(PrRange[1])
    if 'до' in PrRange:
        PrRangeR = int(PrRange[3])
    else:
        PrRangeR = 1000000 #здесь стоило бы использовать sys.maxsize, но так как в стиме точно нет ничего дороже миллиона, то пусть будет так
else:
    PrRangeL = -2
    if 'до' in PrRange:
        PrRangeR = int(PrRange[1])
    else:
        PrRangeR = 1000000
        
df['temp_column'] = [-1 if pr =='' else 0 if (pr =='Бесплатно' or pr =='Демо') else float(pr.replace("pуб.", "").replace(",", ".")) for pr in df["Ordinary Price"]]
df = df[np.logical_and(df['temp_column']>PrRangeL, df['temp_column']<=PrRangeR)]
df = df.drop(['temp_column'], axis = 1)

print("введите диапазон оценок в формате 'от N до M'(0<=N,M<=100). Можно опустить одну часть или оставить пустой ввод для всех игр")
RtRange = input()
RtRange = RtRange.split(" ")
if 'от' in RtRange:
    RtRangeL = int(RtRange[1])
    if 'до' in RtRange:
        RtRangeR = int(RtRange[3])
    else:
        RtRangeR = 101 
else:
    RtRangeL = -2
    if 'до' in RtRange:
        RtRangeR = int(RtRange[1])
    else:
        RtRangeR = 101
        
df['temp_column'] = [-1 if rt =='' else int(rt[:-1]) for rt in df["Rating"]]
df = df[np.logical_and(df['temp_column']>RtRangeL, df['temp_column']<=RtRangeR)]
df = df.drop(['temp_column'], axis = 1)
clear_output()
display(HTML(df.style.set_properties(**{'index-align': 'left', 'text-align': 'left'}).render()))

#и снова сортировка 

print("Отсортируем новые значения")
print("по какой характеристике сортируем? Если не хотите сортировать напишите стоп.")
sleep(1)
Sor = input()

while Sor != "стоп":
    sleep(2)
    if Sor == "вводите нормально":
        print("vvedite normalno")
    elif (Sor in func_dic) or (Sor == "стоп"):
        df = func_dic[Sor](df)
        clear_output()
        display(HTML(df.style.set_properties(**{'index-align': 'left', 'text-align': 'left'}).render()))
        print("Можете отсортировать ещё раз, если хотите вернуться к стандартной сортировке напишите 'Standart', Если хотети прекратить напишите 'стоп'")
    else:
        print("вводите нормально")
    Sor = input()

#время покупок 

print('раз уж мы оставили только самые-самые игры, не пора ли выбрать те из них которые мы хотим купить?')
print('пишите названия игр через запятую')

pd.options.mode.chained_assignment = None
Basket = input()
if Basket =='':
    print("ну чтож пустая корзина, она на то и пустая. 0 Рублей.")
else:
    Basket = Basket.split(', ')
    df_Basket = df[df["Game Name"].isin(Basket)]
    df_Basket["Ordinary Price"] = df_Basket["Ordinary Price"].replace('pуб.','', regex=True).replace(',','.', regex=True).replace('Бесплатно',0, regex=True).replace('Демо',0, regex=True).replace('',0, regex=True)
    df_Basket["Price Now"] = df_Basket["Price Now"].replace('pуб.','', regex=True).replace(',','.', regex=True).replace('Бесплатно',0, regex=True).replace('Демо',0, regex=True).replace('',0, regex=True)
    df_Basket["Price Now"] = df_Basket["Price Now"].astype(float)
    df_Basket["Ordinary Price"] = df_Basket["Ordinary Price"].astype(float)
    Total = df_Basket.sum()["Ordinary Price"]
    Total_Now = df_Basket.sum()["Price Now"]
    print("Сейчас Общая сумма состовляет ", Total)
    print("Без скидок бы это стоило ",Total_Now)
    if Total == 0:
        Sale = 0
    else: 
        Sale = (1 - Total_Now/Total)*100
    print("А значит мы сэкономили ",Total-Total_Now,"рублей или ",Sale, "процентов"  )

sleep(5)

# насортировались? теперь пойдут графики.

clear_output()

df_new = df[["Rating", "Ordinary Price", "Game Name", "Number of Ratings"]]
df_new = (df_new[df_new['Rating']!=''])
df_new = (df_new[df_new['Ordinary Price']!=''])
df_new['Number of Ratings'] = [0 if nrt =='' else int(nrt.replace(",", "")) for nrt in df_new["Number of Ratings"]]
df_new["Ordinary Price"] = ['' if pr =='' else 0 if pr =='Бесплатно' else float(pr.replace("pуб.", "").replace(",", ".")) for pr in df_new["Ordinary Price"]]
df_new['Rating'] = ['' if rt =='' else int(rt[:-1]) for rt in df_new["Rating"]]

i = 0
Sc = []

print("А теперь графики")
print("графики исключают игры без цены, оценки или количества оценок")
print("тут придётся подождать, графики грузятся долго")

Sc.append(px.bar(df_new.sort_values(["Ordinary Price"], ascending=False), x="Game Name", y="Ordinary Price", title = plotly.graph_objs.layout.Title(text = "график распределения цен на игры", x = 0.5) ))

Sc.append(px.scatter(df_new, x="Ordinary Price", y="Rating", trendline="lowess", hover_name="Game Name", title = plotly.graph_objs.layout.Title(text = "график зависимости цены на игру и её оценки", x = 0.5) ))

Sc.append(px.scatter(df_new, x="Ordinary Price", y="Number of Ratings", trendline="lowess", hover_name="Game Name", title = plotly.graph_objs.layout.Title(text = "график зависимости цены на игру и её количества оценок", x = 0.5) ))

Sc.append(px.scatter(df_new, x="Number of Ratings", y="Rating", trendline="lowess", hover_name="Game Name" , title = plotly.graph_objs.layout.Title(text = "график зависимости количества оценок на игру и её оценки", x = 0.5)))

Sc.append("А где график? A нет графика"
          "¯\uFF3C_(ツ)_/¯")

button = Button(description="следующий график")
display(button)

def on_button_clicked(b):
    global i
    clear_output()
    if i <len(Sc):
        display(Sc[i])
        if i <len(St)-1:
            display(button)
    i = i+1

button.on_click(on_button_clicked)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7ca4e2280c5d> in on_button_clicked(b)
#     249     global i
#     250     clear_output()
# --> 251     if i <len(Sс):
#     252         display(Sc[i])
#     253         if i <len(St)-1:
#
# NameError: name 'Sс' is not defined

# %% [markdown]
# вторая чать проекта основанная на API

# %% [markdown]
# Программа может работать долго так как обрабатывается большой массим данных

# %% [markdown]
# Так как для ботов нельзя получить больше 500 значений, то некоторые года будут отображать именно это значение

# %%
enterpoint = "https://en.wikipedia.org/w/api.php"
params = {"action": "query", 
          "list": "categorymembers",
          "cmtitle":"Category:Video_games_by_year", 
          "cmlimit": 100,
          "format": "json"}
r = requests.get(enterpoint, params=params)
titles = [item['title'] for item in r.json()['query']["categorymembers"]]
titles = titles[3:-3]
years = [int(t[9:13]) for t in titles]
G = []
for title in titles:
    params = {"action": "query", 
          "list": "categorymembers",
          "cmtitle":title, 
          "cmlimit":999,
          "format": "json"}
    r = requests.get(enterpoint, params=params)
    G.append([item['title'] for item in r.json()['query']["categorymembers"]])
Games_by_year = dict(zip(years, G))
for i in range(1947, 2018):
    if not (i in Games_by_year.keys()):
        Games_by_year[i] = ['Нет Игр']
Num_of = {}
for key in Games_by_year.keys():
    if Games_by_year[key] == ['Нет Игр']:
        Num_of[key] = 0
    else:
        Num_of[key] = len(Games_by_year[key])
        
print('вводите год и будет выведено сколько игр вышло в этом году и их названия. Чтобы остановиться напишите 0')    

year = int(input('Введите год: '))

while year != 0:
    clear_output()
    if Num_of[year] < 500:
        print('в', year, 'вышло игр:', Num_of[year], '. А именно:')
        for game in Games_by_year[year]:
            print(game)
    else:
        print('в', year, 'вышло более 500 игр, в том числе:')
        for game in Games_by_year[year]:
            print(game)      
    year = int(input('Введите следующий год: '))
# Out:
# в 2008 вышло более 500 игр, в том числе:
# 1 vs. 100 (2008 video game)
# 11eyes: Tsumi to Batsu to Aganai no Shōjo
# 5 (visual novel)
# 12Riven: The Psi-Climinal of Integral
# 100 Classic Book Collection
# 101-in-1 Explosive Megamix
# 428: Shibuya Scramble
# 1942: Joint Strike
# Aces of the Galaxy
# Active Life: Outdoor Challenge
# ADK Damashii
# Advance Wars: Days of Ruin
# Adventure Rock
# AdventureQuest Worlds
# Aether (video game)
# Afrika (video game)
# Age of Booty
# Age of Conan
# Age of Empires: Mythologies
# Ai Space
# Aion (video game)
# Airport Mania
# Alien Crush Returns
# All Star Cheer Squad
# Allied Ace Pilots
# Alone in the Dark (2008 video game)
# American McGee's Grimm
# AMF Bowling World Lanes
# Animal Boxing
# Animal Crossing: City Folk
# Anti-Japan War Online
# Ao Oni
# Aoi Shiro
# Ape Quest
# Aquanaut's Holiday: Hidden Memories
# Aquia (video game)
# Arkanoid DS
# Armand and the Foppish Hat
# Armored Brigade (video game)
# Armored Core: For Answer
# Army Men: Soldiers of Misfortune
# Army of Two
# Art of Murder: Hunt for the Puppeteer
# Art Style
# Asda Story
# Asphalt 4: Elite Racing
# Assassin's Creed: Altaïr's Chronicles
# Assault Heroes 2
# AssaultCube
# Asterix at the Olympic Games (video game)
# Astro Tripper
# Asura (video game)
# Atlantica Online
# Audiosurf
# Auditorium (video game)
# Aurora Feint
# Aurora: The Secret Within
# Avalon Code
# Avatar: The Last Airbender – Into the Inferno
# Away: Shuffle Dungeon
# Azada: Ancient Magic
# Baby Life
# Baja: Edge of Control
# Bananagrams (online game)
# Bang Attack
# Bangai-O Spirits
# Banjo-Kazooie: Nuts & Bolts
# Barbie Fashion Show: An Eye for Style
# Barkley, Shut Up and Jam: Gaiden
# Barnyard Blast: Swine of the Night
# Battle of the Bands (video game)
# Battlefield: Bad Company
# Battlezone (2008 video game)
# Beat'n Groovy
# Beatmania IIDX 16: Empress
# Beijing 2008 (video game)
# Bejeweled Twist
# Belief & Betrayal
# Bella Sara (video game)
# Ben 10: Alien Force (video game)
# Ben Jordan: Paranormal Investigator
# Ben There, Dan That!
# Best of Tests DS
# Beyond Protocol
# Big Beach Sports
# Bigfoot: Collision Course
# Biology Battle
# Bionic Commando Rearmed
# Blast Works: Build, Trade, Destroy
# BlazBlue: Calamity Trigger
# Bleach: The 3rd Phantom
# Blitz: The League II
# Block Breaker Deluxe 2
# Blue Dragon Plus
# Boingz
# Bolt (video game)
# Bomberman 2
# Bomberman Blast
# Bomberman Touch
# BoneTown
# Boogie Bunnies
# Boogie Superstar
# Boom Blox
# Robert Ludlum's The Bourne Conspiracy
# Braid (video game)
# Brain Age Express
# Brain Quest Grades 3 & 4
# Brain Quest Grades 5 & 6
# Brain Voyage
# Brothers in Arms (2008 video game)
# Brothers in Arms: Art of War
# Brothers in Arms: Double Time
# Brothers in Arms: Hell's Highway
# Brothers in Arms: Hour of Heroes
# Bruiser and Scratch
# Burnout Paradise
# Buzz! Junior: Ace Racers
# Buzz! Junior: Dino Den
# Buzz!: Brain Bender
# Buzz!: Master Quiz
# Buzz!: Quiz TV
# Buzz!: The Pop Quiz
# Buzz!: The Schools Quiz
# Cabela's Dangerous Hunts 2009
# Cal Ripken's Real Baseball
# Call of Duty: World at War
# Call of Duty: World at War (Nintendo DS)
# Call of Duty: World at War – Final Fronts
# Calvin Tucker's Redneck Jamboree
# Candace Kane's Candy Factory
# Captain Rainbow
# CarneyVale: Showtime
# Casebook (video game)
# Casper's Scare School (video game)
# Castle Crashers
# Castlevania Judgment
# Castlevania: Order of Ecclesia
# Catan (2008 video game)
# Catching Features
# Cate West: The Vanishing Files
# Celebrity Sports Showdown
# Championship Pony
# Chaos;Head
# The Cheetah Girls: Passport to Stardom
# Chess Crusade
# Chess with Friends
# Chicktionary
# Chocolatier 2: Secret Ingredients
# Chronicles of Mystery: The Scorpio Ritual
# The Chronicles of Narnia: Prince Caspian (video game)
# The Chronicles of Spellborn
# Chronotron
# Chrysler Classic Racing
# Chuck Norris: Bring On the Pain
# Civilization IV: Colonization
# Civilization Revolution
# Class of Heroes
# Clear Vision (video game)
# Club Penguin: Elite Penguin Force
# The Club (video game)
# Clue Classic
# Code (video game)
# Code Geass
# Code Lyoko: Fall of X.A.N.A.
# Coded Soul: Uketsugareshi Idea
# Coffeetime Crosswords
# Collapse (2008 video game)
# Colour Cross
# Combat Arms (video game)
# Combat of Giants
# Command & Conquer 3: Kane's Wrath
# Command & Conquer: Red Alert 3
# Command and Destroy
# Commander in Chief (video game)
# Commanders: Attack of the Genos
# Commando: Steel Disaster
# Condemned 2: Bloodshot
# Conflict: Denied Ops
# The Continuum
# Cooking Guide: Can't Decide What to Eat?
# Cooking Mama: World Kitchen
# Corpse Craft: Incident at Weardd Academy
# Corpse Party
# Cory in the House (video game)
# Cosmic Break
# Counter-Strike Online
# Cradle of Rome
# Crash Bandicoot Nitro Kart 3D
# Crash Commando
# Crash: Mind over Mutant
# Crazy Mouse
# Crazy Penguin Catapult
# Crimson Gem Saga
# Critter Crunch
# Critter Round-Up
# Cross Edge
# Crosswords DS
# Crowns of Power
# Crysis Warhead
# Crystal Defenders
# CSI: NY (video game)
# Cubello
# Curse of the Pharaoh: The Quest for Nefertiti
# Dance Dance Revolution Hottest Party 2
# Dance Dance Revolution Universe 3
# Dance Dance Revolution X
# Dancing with the Stars: We Dance!
# Dangerous High School Girls in Trouble!
# Dark Horizon
# Dark Room Sex Game
# Dark Sector
# The Dark Spire
# Darkest Hour: Europe '44-'45
# Dash of Destruction
# De Blob
# Dead Frontier
# Dead Space (video game)
# Deadliest Catch: Alaskan Storm
# Dear Esther
# Death Track: Resurrection
# Deca Sports
# Defend Your Castle
# Defense Grid: The Awakening
# Derby Time Online
# Derek Jeter Pro Baseball 2008
# The Destiny of Zorro
# Destroy All Humans! Big Willy Unleashed
# Destroy All Humans! Path of the Furon
# Devil May Cry 4
# The Devil on G-String
# Devil Summoner 2: Raidou Kuzunoha vs. King Abaddon
# DigiDrummer
# Digimon World Championship
# Digital Combat Simulator
# Dirk Dagger and the Fallen Idol
# Disaster: Day of Crisis
# Disgaea 3
# Disney Friends
# Disney Sing It
# Disney Sing It! – High School Musical 3: Senior Year
# Disney Think Fast
# Dissidia Final Fantasy
# DJMax Portable Black Square
# DJMax Portable Clazziquai Edition
# DJMax Technika
# DJMax Trilogy
# DoDonPachi Resurrection
# Dokapon Journey
# Doki Doki Majo Shinpan 2 Duo
# Domain of Heroes
# Don King Presents: Prizefighter
# Doodle Hex
# Dora the Explorer video games
# Double D Dodgeball
# Dr. Mario Express
# Dr. Mario Online Rx
# Dracula 3: The Path of the Dragon
# Dracula: Origin
# Dragon Ball Z: Burst Limit
# Dragon Ball Z: Infinite World
# Dragon Ball: Origins
# Drakensang: The Dark Eye
# Drawn to Life: SpongeBob SquarePants Edition
# Dream Chronicles 2: The Eternal Maze
# Droid Assault
# DT Carnage
# Ducati Moto
# Duel Love
# Dynasty Warriors: Gundam 2
# Echochrome
# Edelweiss (visual novel)
# Edge (video game)
# Ef: A Fairy Tale of the Two
# Efteling Tycoon
# Elebits: The Adventures of Kai and Zero
# Elefunk
# Elminage
# Emergency Heroes
# Emergency Mayhem
# Tom Clancy's EndWar
# ERepublik
# Eternal Fantasy
# Eternal Poison
# Eternity's Child
# Ether Saga Odyssey
# Etrian Odyssey II
# Euro Truck Simulator
# Europa Universalis: Rome
# Exploit (video game)
# Fable II
# Fable II Pub Games
# FaceBreaker
# FairlyLife
# Fallout 3
# Family Glide Hockey
# Family Park Tycoon
# Family Table Tennis
# Fancy Pants Adventures
# Fantage
# Fantastic Contraption (2008 video game)
# Far Cry 2
# Farming Simulator
# Fatal Frame: Mask of the Lunar Eclipse
# Fate of Hellas
# Fate/unlimited codes
# Fate: Undiscovered Realms
# Ferrari Challenge: Trofeo Pirelli
# Ferrari GT: Evolution
# Fieldrunners
# FIFA 09
# FIFA Street 3
# Final Fantasy Crystal Chronicles: My Life as a King
# Final Fantasy IV: The After Years
# Fire Emblem: Shadow Dragon
# Flipnote Studio
# Foldit
# Football Manager 2009
# Football Manager Live
# Ford Racing (series)
# Fortune Arterial
# Fortune Summoners: Secret of the Elemental Stone
# Forumwarz
# Fossil Fighters
# Fracture (video game)
# Frogger 2 (Xbox Live Arcade)
# From the Abyss
# Frontlines: Fuel of War
# Fun! Fun! Minigolf
# Fun4All
# FunOrb
# Furifuri
# FutureU
# Galactic Civilizations II: Twilight of the Arnor
# Galaga Legions
# Galcon
# Gallop & Ride
# Gang Garrison 2
# Garfield Gets Real (video game)
# GauntNet
# Gears of War 2
# GemCraft
# Geneforge 5: Overthrow
# GeoDefense
# Geometry Wars: Retro Evolved 2
# Geon (video game)
# George of the Jungle and the Search for the Secret
# Get Outta My Face
# Ghajini – The Game
# Gin Rummy (video game)
# Glory of Heracles
# Go! Go! Break Steady
# God of War: Chains of Olympus
# Goin' Downtown
# Gold's Gym: Cardio Workout
# Golden Axe: Beast Rider
# Golden Balls (video game)
# The Golden Horde (video game)
# Golf: Tee It Up!
# GoPets: Vacation Island
# Gothic 3: Forsaken Gods
# Gothic 3: The Beginning
# Gradius ReBirth
# Grand Theft Auto IV
# The Graveyard (video game)
# Gravity Bone
# Groovin' Blocks
# GTI Club+: Rally Côte d'Azur
# GTR Evolution
# Guilty Gear X2 updated versions
# Guinness World Records: The Videogame
# Guitar Hero: Aerosmith
# Guitar Hero World Tour
# Guitar Hero: On Tour series
# Guitar Praise
# Guitar Rock Tour
# Gyrostarr
# Hail to the Chimp
# Hammerin' Hero
# Happy Farm
# Happy Tree Friends: False Alarm
# The Hardy Boys: The Hidden Theft
# Harpooned
# Haruhi Suzumiya
# Haruiro Ouse
# Harvest Moon DS: Grand Bazaar
# Harvest Moon DS: Sunshine Islands
# Harvest Moon: Animal Parade
# Harvest: Massive Encounter
# Harvey Birdman: Attorney at Law (video game)
# Hasbro Family Game Night
# Hayate the Combat Butler
# Haze (video game)
# Heileen
# Helix (video game)
# Hell's Kitchen: The Game
# Hellboy: The Science of Evil
# Hello Kitty Online
# Hello Kitty: Big City Dreams
# Help Wanted (video game)
# Hero of Sparta
# Hero's Saga Laevatein Tactics
# Heroes of Might and Magic Online
# High School Musical 2: Work This Out!
# High School Musical 3: Senior Year (video game)
# High School Musical 3: Senior Year Dance
# Hinterland (video game)
# History Civil War: Secret Missions
# Hockey Allstar Shootout
# Hoshiuta
# The House of the Dead 2 & 3 Return
# Hunted Forever
# I Love Katamari
# Iced!
# The Idolmaster Live For You!
# Iji
# Ikariam
# Ikki Tousen
# The Immortals of Terra: A Perry Rhodan Adventure
# Imperium Romanum (video game)
# Inazuma Eleven
# The Incredible Hulk (2008 video game)
# The Incredible Maze
# Incredibots
# Infinite Undiscovery
# Initial D Extreme Stage
# InLiving
# Insecticide (video game)
# IRacing
# Iron Chef America: Supreme Cuisine
# Iron Grip: Warlord
# Iron Man (video game)
# Ironclads: American Civil War
# J.League Winning Eleven 2008 Club Championship
# Jam with the Band
# JamLegend
# Janline
# Jawa: Mammoth to Himitsu no Ishi
# Jeep Thrills
# JellyCar
# Jinkō Shōjo 3
# Journey to the Center of the Earth (Nintendo DS)
# Jubeat
# Jumper: Griffin's Story (video game)
# Kamen Rider Battle: Ganbaride
# KamiCrazy
# Kanojo × Kanojo × Kanojo
# Kanokon
# Kara no Shōjo
# Karaoke Joysound
# Kawasaki Jet Ski
# Kawasaki Snowmobiles
# Kenka Bancho: Badass Rumble
# Kimi ga Yobu, Megido no Oka de
# Kimi no Yusha
# King's Bounty: The Legend
# A Kingdom for Keflings
# Kingdom Hearts Coded
# Kingdom Hearts Mobile
# Kirakira (visual novel)
# Kirby Super Star
# Klonoa (2008 video game)
# Knights in the Nightmare
# KORG DS-10
# Kotoba no Puzzle: Mojipittan
# Kumatanchi
# Kung Fu Panda (video game)
# Kung Fu Panda: Legendary Warriors
# Kwari
# Larva Mortus
# The Last Guy
# The Last Remnant
# Leapster
# Left 4 Dead
# The Legend of Kage 2
# The Legend of Spyro: Dawn of the Dragon
# Legend of Wukong
# Legendary (video game)
# The Legendary Starfy (video game)
# Legions: Overdrive
# Lego Batman: The Videogame
# Lego Indiana Jones: The Original Adventures
# Let's Catch
# Let's Play Pet Hospitals
# Let's Tap
# Lightbot
# Linger in Shadows
# Lips (video game)
# Little Busters!
# Little League World Series Baseball
# Little Red Riding Hood's Zombie BBQ
# LittleBigPlanet (2008 video game)
# Littlest Pet Shop (video game)
# Lock's Quest
# LocoRoco 2
# Looney Tunes: Cartoon Conductor
# The Lord of the Rings Online: Mines of Moria
# Lord of Vermilion
# Lost Cities (video game)
# The Lost Crown: A Ghost-Hunting Adventure
# Lost in Blue: Shipwrecked

# %% [markdown]
# Ссылка на саму категорию: https://en.wikipedia.org/wiki/Category:Video_games_by_year

# %% [markdown]
# Кнопка считающая цифры, удивительно что вы сюда дошли

# %%
#/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
x = 0
a = range(1, 100)
button = Button(description="супер кнопка")
display(button)

def on_button_clicked(b):
    global x
    clear_output()
    if x <len(a):
        display(a[x])
        display(button)
    x = x+1

button.on_click(on_button_clicked)
